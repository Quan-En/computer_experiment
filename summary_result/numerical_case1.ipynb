# %%
import sys
sys.path.append("..")
from utils import utils, plot
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Without noise

# %%
mo_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-0/"+str(i+1)+".pkl") for i in range(100)]
mt_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-0/"+str(i+1)+".pkl") for i in range(100)]

# %%
plt.rcParams.update({'font.family':'Times New Roman', 'font.size': 20})
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mo_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mo_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mo_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP(w/o noise)", "MOQQGP(w/o noise)"],
    color_list=["green", "black"],
)

# %% [markdown]
# ## 2. With Noise ($\sigma=0.01$)

# %%
mo_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-01/"+str(i+1)+".pkl") for i in range(100)]
mt_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-01/"+str(i+1)+".pkl") for i in range(100)]

mopp_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-01_pp/"+str(i+1)+".pkl") for i in range(100)]
mtpp_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-01_pp/"+str(i+1)+".pkl") for i in range(100)]

# %%
plt.rcParams.update({'font.family':'Times New Roman', 'font.size': 20})
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mo_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mo_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mo_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP+OEHVI", "MOQQGP+OEHVI"],
    color_list=["green", "black"],
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mo_list],
        [sub_dict["cr"] for sub_dict in mopp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mo_list],
        [sub_dict["time_cost"] for sub_dict in mopp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mo_list],
        [sub_dict["ei_value"] for sub_dict in mopp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MOQQGP+OEHVI", "MOQQGP+PEHVI"],
    color_list=["black", "red"],
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mtpp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mtpp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mtpp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP+OEHVI", "MTQQGP+PEHVI"],
    color_list=["green", "blue"],
)

# %% [markdown]
# # 3. With Noise ($\sigma=0.025$)

# %%
mo_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-025/"+str(i+1)+".pkl") for i in range(100)]
mt_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-025/"+str(i+1)+".pkl") for i in range(100)]

mopp_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-025_pp/"+str(i+1)+".pkl") for i in range(100)]
mtpp_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-025_pp/"+str(i+1)+".pkl") for i in range(100)]

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mo_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mo_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mo_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP+OEHVI", "MOQQGP+OEHVI"],
    color_list=["green", "black"],
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mo_list],
        [sub_dict["cr"] for sub_dict in mopp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mo_list],
        [sub_dict["time_cost"] for sub_dict in mopp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mo_list],
        [sub_dict["ei_value"] for sub_dict in mopp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MOQQGP+OEHVI", "MOQQGP+PEHVI"],
    color_list=["black", "red"],
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mtpp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mtpp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mtpp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP+OEHVI", "MTQQGP+PEHVI"],
    color_list=["green", "blue"],
)

# %% [markdown]
# # 4. With Noise ($\sigma=0.05$)

# %%
mo_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-05/"+str(i+1)+".pkl") for i in range(100)]
mt_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-05/"+str(i+1)+".pkl") for i in range(100)]

mopp_list = [utils.load_object("../experiment_result/numerical/c1_moqqgp_ss6_gs20_ns0-05_pp/"+str(i+1)+".pkl") for i in range(100)]
mtpp_list = [utils.load_object("../experiment_result/numerical/c1_mtqqgp_ss6_gs20_ns0-05_pp/"+str(i+1)+".pkl") for i in range(100)]

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mo_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mo_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mo_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP", "MOQQGP"],
    color_list=["green", "black"],
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mo_list],
        [sub_dict["cr"] for sub_dict in mopp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mo_list],
        [sub_dict["time_cost"] for sub_dict in mopp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mo_list],
        [sub_dict["ei_value"] for sub_dict in mopp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MOQQGP+OEHVI", "MOQQGP+PEHVI"],
    color_list=["black", "red"], #blueviolet
)

# %%
plot.PlotHisQuan(
    cr_lists=[
        [sub_dict["cr"] for sub_dict in mt_list],
        [sub_dict["cr"] for sub_dict in mtpp_list],
    ],
    time_lists=[
        [sub_dict["time_cost"] for sub_dict in mt_list],
        [sub_dict["time_cost"] for sub_dict in mtpp_list],
    ],
    eiv_lists=[
        [sub_dict["ei_value"] for sub_dict in mt_list],
        [sub_dict["ei_value"] for sub_dict in mtpp_list],
    ],
    step_num_list=[20,19,19],
    model_name_list=["MTQQGP+OEHVI", "MTQQGP+PEHVI"],
    color_list=["green", "blue"],
)

# %% [markdown]
# # Estimation result (with nosie $\sigma=0.05$)

# %%
plot.PlotTrueCorr(mt_list, r"(with noise $\sigma_1=\sigma_2=0.05)$")

# %%
plot.PlotNoiseEstimation(mt_list, step=20, suptitle="MTQQGP+OEHVI")

# %%
plot.PlotNoiseEstimation(mtpp_list, step=20, suptitle="MTQQGP+PEHVI")

# %%
plot.PlotDataStepCorr(mt_list, start_index=12, end_index=32)
plot.PlotDataStepCorr(mtpp_list, start_index=12, end_index=32)

# %%
plot.PlotCorrEstimation(mt_list, step=20)
plot.PlotCorrEstimation(mtpp_list, step=20)
